# %%
# pip install pythainlp
# pip install gensim
# conda install -c conda-forge wordcloud

# %%
import pythainlp

# %%
import pandas as pd

# %%
from pythainlp.tokenize import word_tokenize
text = 'ผมรักคุณนะครับโอเคบ่พวกเราเป็นคนไทยรักภาษาไทยภาษาบ้านเกิด'

# %%
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอ', 'เค', 'บ่', 'พวก', 'เรา', 'เป็น', 'คน', 'ไทย', 'รัก', 'ภาษา', 'ไทย', 'ภาษา', 'บ้าน', 'เกิด']
# a = word_tokenize(text, engine='icu')
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']
b = word_tokenize(text, engine='mm')
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']
c = word_tokenize(text, engine='pylexto')
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']
d = word_tokenize(text, engine='newmm')
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คน', 'ไทย', 'รัก', 'ภาษา', 'ไทย', 'ภาษา', 'บ้านเกิด']
e = word_tokenize(text, engine='wordcutpy')

# print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']
# ['ผม', 'รัก', 'คุณ', 'นะ', 'ครับ', 'โอเค', 'บ่', 'พวกเรา', 'เป็น', 'คนไทย', 'รัก', 'ภาษาไทย', 'ภาษา', 'บ้านเกิด']

# %%
from pythainlp.word_vector import similarity

# %%
similarity('อ้วน','ผอม')
# Out:
# 0.4360441

# %%
grab_ans = """
ทางกรมขนส่งไม่โอเคกับรถป้ายดำที่จะนำมาทำเป็นรถสาธารณะ เพราะ เสียภาษีน้อยกว่ารถปกติ แต่การทำงานเราไม่ใช่พนักงานประจำเหมือนรถแท็กซี่ ดังนั้นมันจะผิด พรบ อย่างเดียว ไม่ได้ผิดกฎหมาย
แต่จะมีปัญหาช่วง Low season คือลูกค้าจะน้อย และทางกรมขนส่งทราบแต่ก็ไม่ได้มีมาตรการอะไร เพราะถ้าช่วง low season ลูกค้าทั้งรถแดง และgrab car ก็จะน้อยลง คนให้บริการก็จะมีการโวยวายนิดนึง
ไม่มีเพราะเป็นบริษัท กฎก็จะเป็นของ Grab
ช่วงนี้ก็จะไม่ค่อยมี แต่จะมีปัญหาช่วง Low season และอาจจะมีปัญหากับคนขับรถแดงที่ไม่ได้ขับแกรบ อย่างเช่นเวลาเจอหน้ากัน อาจจะตะโกนด่ากันเลย
เยอะ ยิ่วงที่เศรษฐกิจไม่ดี ก็จะมาสมัครกัน คนขับรถแดงก็จะมาสมัครแกรบรถแดง แต่แกรบรถแดงจะไม่ บูมเท่าแกรบคาร์เพราะว่าเวลาเรียกรถแดงนั้นจำเป็นที่จะต้องเหมา
ส่วนใหญ่จะเรียกแกรบคาร์  แต่ถ้าเรียกแกรบรถแดงมักจะเป็นชาวต่างชาติมากกว่า คนไทยไม่ค่อยเรียก
พอพอกันแต่รถแดงจะแพงกว่าหน่อย เพราะว่าต้องเหมา เวลาจะเรียก อาจจะเรียกประมาณคราวละ 67คน
ที่มาเพราะเห็นช่องทางเพราะตอนแรกมีบริษัทอื่นอยู่ที่เชียงใหม่ แต่ตอนนี้ปิดไปแล้ว
คิดว่าเป็นเมืองที่น่าจะมีคนใช้บริการเยอะเลยมาเปิดบริษัทที่นี่
พี่คิดว่ามันง่ายกว่า 1 เช่น สามารถเรียกมารับหน้าบ้านได้ 2 มีส่วนลด  3 คนนั่งแกรบไม่ใช่แค่นักศึกษา แต่คนขับมานั่งก็มี เช่นมาช่วยกัน
มีทั้งคนขับแบบ full time และ part time แต่จะไม่แนะนำให้ขับ แบบ full time เพราะตอนแรกรายได้อาจจะเยอะ แต่พอผ่านไปรายได้อาจจะไม่ได้เยอะแบบช่วงแรกๆ เพราะบางทีก็ไม่มีลูกค้า และช่วงแรกของบริษัทจะมีโปรโมชั่นทำให้ได้รายได้เยอะกว่าช่วงหลังๆ
คนร้องเรียนส่วนใหญ่จะร้องเรียนผ่านทาง call center มากกว่า จะไม่ได้มาร้องเรียนทางศูนย์แกรบ แต่บางทีที่มาร้องเรียนมักจะมาร้องเรียนเรื่องของหายมากกว่า
แต่รถยนต์ก็ไม่ค่อยจะมีปัญหา เพราะถ้ามีปัญหาบางทีก็จะถูกปิดระบบไปเลย เช่น คนขับกับรถไม่ตรงกันบ้าง รถอายุเกินบ้าง หรือเอาคนอื่นมานั่งด้วยบ้าง
มีปัญหาอย่างเช่น คนขับอายุเยอะก็จะใช้แอพไม่ค่อยเป็น กดผิดบ้าง แต่ปกติจะมีอบรมก่อนมาขับ
เช่นวัน ศุกร์ เสาร์ อาทิตย์ หรือเวลากลางคืนที่มีคนไปเที่ยวผับ ก็จะมีคนเรียกเยอะ แต่คนขับน้อย ราคาก็จะแพงหน่อย
คนสมัครค่อนข้างเยอะ แต่จะบอกตัวเลขไม่ได้เพราะบางทีมีคนสมัครออนไลน์ก็จะไม่รู้
ส่วนใหญ่ใช้รถแดงกะรถส่วนตัว คนเชียงใหม่ใช้รถยนต์เป็นส่วนใหญ่ แต่ถ้ารถแดงจะเป็นคนอายุเยอะที่ขับรถไม่ได้
เมื่อเทียบกันแล้วคนที่ขึ้นรถแดงมักจะเป็นนักท่องเที่ยวมากกว่าคนพื้นเมือง
คิดว่าคนเชียงใหม่ไม่ได้ใช้รถส่วนตัวน้อยลง เพราะว่าเค้าไม่ได้ใช้รถแกรบตลอด ส่วนใหญ่จะใช้เวลาไปเที่ยว และเค้าไม่ได้เที่ยวทุกวัน ดังนั้น คนที่ใช้แกรบทุกวันน่าจะเป็นนนักท่องเที่ยวมากกว่า
การที่แกรบเค้ามาเปิดในเชียงใหม่น่าจะเป็นการส่งเสริมให้นักท่องเที่ยวใช้มากกว่า
ช่วงนี้น่าจะเป็นคนไทยมากกว่า เพราะคนต่างชาติไม่ได้เที่ยว แต่ถ้าคนไทยที่เรียกส่วนใหญ่จะเป็นนักศึกษา
เกือบทุกอำเภอ แต่อำเภอไกลๆก็ไม่เท่าไหร่ แต่พยายามที่จะแผ่ขยายอยู่ เพราะว่าเราจะอิงตามคนขับ ถ้าคนขับอยู่อำเภอไกลๆ เวลาที่มีลูกค้าเรียกเค้าก็จะได้งานแต่ในเมืองก็จะแน่นกว่า
ตอนนี้ไม่ค่อยเน้นเรื่องคนขับแกรบคาร์ แต่จะเน้น แกรบฟู้ดมากกว่า  ดังนั้นจึงไม่ได้มีขยาย เพราะไม่มีคู่แข่งสามารถอยู่ได้อยู่แล้ว
ส่วนใหญ่คละกัน เช่นคนสูงอายุ นักศึกษา หรือวัยทำงาน 2040 ถ้าอายุน้อยกว่านี้ก็จะเป็นเด็กก็มีบ้างแต่น้อย แต่จริงๆแล้วส่วนใหญ่ที่ใช้น่าจะเป็นนักศึกษา หรือวัยทำงาน นักศึกษาถ้าไม่มีโค้ดก็ไม่ค่อยใช้
แกรบเรื่องเงินจะได้ไวกว่า คือได้วันต่อวัน เมื่อเทียบกับ อูเบอร์ คือจะได้เป็นสัปดาห์ แต่ถ้าในเรื่องของจำนวนคนขับน่าจะพอๆกัน
 ฝั่งลูกค้าโค้ดเยอะกว่า แอพอื่น และมีการพัฒนาเรื่องหมุด คือหมุดมีความเป้ะขึ้น เมื่อเทียบกับเมื่อก่อนที่อาจจะพลาดบ่อย
ของที่เชียงใหม่ยังไม่มี มีแต่ที่กรุงเทพ
ประมาณ สี่ปีแล้ว แต่แกรบแท็กซี่มีก่อน คนใช้แกรบคาร์มากกว่า เพราะแท็กซี่แพงกว่า แต่บางคนอาจจะชอบกว่า เพราะมันสบายกว่า คนที่ชอบมักจะเป็นคนที่มีเงินเยอะเยอะ เพราะมันต้องมีค่าเรียก ค่ามิเตอร์ มันจะแพงกว่าปกติ
ไม่มีเพราะว่า คนที่สมัครเค้าไม่ได้มาขับตลอด อย่างเช่น บางทีสมัครไว้ แต่ไปต่างจังหวัด หรือบางทีอาจจะต้องไปเลี้ยงลูก ดังนั้นจำนวนคนขับมันจะมีการเพิ่มลดอยู่ตลอดเวลา ยังไม่ถึงขั้นที่คนขับเยอะเกินไป แต่ถ้าคนขับแกรบเยอะเกินไป ทางบริษัทก็มีหน้าที่ต้องหาลูกค้าให้ เช่นต้องทำ marketing เพิ่ม
คนขับจะขาดในช่วงเทศกาลมากกว่า
เบื้องต้นจะเป็นการออฟไลน์มากกว่า เพราะน่าจะได้ผลมากกว่า เช่นป้าย การเปิดบูธ ใบปลิว อาจจะ effective กว่าพวกออนไลน์ เพราะพวกออนไลน์จะต้องใช้เงินฟาด ปล่อย code ไปยังไงลูกค้าก็ใช้อยู่แล้ว
ใช่ เพราะว่า ได้ยินมาว่า มีการไปคุยกับรถแดงว่าจะมีการโปรโมทให้ แต่จะขอหักค่าคอมมิชชั่นในการใช้แอพ แต่รถแดงไม่ยอม บริษัทก็เลยไม่มีทุนที่จะทำให้
marketting ของบริษัท แกรบ คนขับจะโดนหัก 25% เพื่อเอามาโปรโมท
การบริการ เพราะ ทางบริษัทจะควบคุมคนขับไม่ค่อยได้ อย่างในกรณีรถแดง จะเป็นเนเจอร์ของเค้า อย่างเช่น ถ้าบอกว่าถ้าเค้ายกเลิกลูกค้าบ่อยจะทำการปิดระบบนะ เค้าก็ยังจะยกเลิกลูกค้าอยู่ดี แบบไม่ได้กลัวการถูกปิดระบบ ซึ่งต่างจากคนขับแกรบคาร์ ที่เค้าพยายามที่จะบริการให้ดี แต่คนขับรถแดงบางคนที่ดีก็มีไม่ได้แย่ทั้งหมด คนขับรถแดงที่เป็นแกรบยาวๆก็มี่
อย่างการบริการมันก็มีช่องโหว่อยู่ อย่างเช่น มีการโกง ทุจริต แต่เราทำอะไรไม่ได้ ต้องให้ระบบจัดการ
ยังมีปัญหาอยู่ แต่ทางแกรบก็จะมีมาตรการ เช่น มีการเตือน ดังนั้นคนขับแกรบอาจจะกลัวโดนปิดระบบ เพราะเค้าทำเป็นงาน partime
แก้ยาก การพิจารณาจะมีแค่ในกรุงเทพ เค้าจะพิจารณาเป็นเคสๆไปว่าถูกปิดเพราะอะไร ร้ายแรงมั้ย ทำมาแล้วกี่ครั้ง
ไม่เพราะต้องมีการตรวจประวัติก่อน เช่น มีคดีเมาแล้วขับ ไม่เกิน 7 ปี ห้ามขับ ยาเสพติดไม่เกิน 7 ปี กรณีทำร้ายร่างกายห้ามขับ
"""

# %%
word_tokenize(grab_ans, engine='wordcutpy')
# Out:
# ['\n',
#  'ทาง',
#  'กรม',
#  'ขนส่ง',
#  'ไม่',
#  'โอเค',
#  'กับ',
#  'รถ',
#  'ป้าย',
#  'ดำ',
#  'ที่จะ',
#  'นำมา',
#  'ทำเป็น',
#  'รถ',
#  'สาธารณะ',
#  ' ',
#  'เพราะ',
#  ' ',
#  'เสียภาษี',
#  'น้อยกว่า',
#  'รถ',
#  'ปกติ',
#  ' ',
#  'แต่',
#  'การทำงาน',
#  'เรา',
#  'ไม่',
#  'ใช่',
#  'พนักงานประจำ',
#  'เหมือน',
#  'รถแท็กซี่',
#  ' ',
#  'ดังนั้น',
#  'มัน',
#  'จะ',
#  'ผิด',
#  ' ',
#  'พร',
#  'บ',
#  ' ',
#  'อย่าง',
#  'เดียว',
#  ' ',
#  'ไม่',
#  'ได้',
#  'ผิดกฎหมาย',
#  '\n',
#  'แต่',
#  'จะ',
#  'มีปัญหา',
#  'ช่วง',
#  ' ',
#  'Low',
#  ' ',
#  'season',
#  ' ',
#  'คือ',
#  'ลูกค้า',
#  'จะ',
#  'น้อย',
#  ' ',
#  'และ',
#  'ทาง',
#  'กรม',
#  'ขนส่ง',
#  'ทราบ',
#  'แต่',
#  'ก็',
#  'ไม่',
#  'ได้',
#  'มี',
#  'มาตรการ',
#  'อะไร',
#  ' ',
#  'เพราะ',
#  'ถ้า',
#  'ช่วง',
#  ' ',
#  'low',
#  ' ',
#  'season',
#  ' ',
#  'ลูกค้า',
#  'ทั้ง',
#  'รถ',
#  'แดง',
#  ' ',
#  'และ',
#  'grab',
#  ' ',
#  'car',
#  ' ',
#  'ก็',
#  'จะ',
#  'น้อยลง',
# ...

# %%
from pythainlp.word_vector import sentence_vectorizer
sentence1 = grab_ans
sv1 = sentence_vectorizer(sentence1, use_mean=True)
sentence2 = 'เเอร์เย็นมาก'
sv2 = sentence_vectorizer(sentence2, use_mean=True)
sentence3 = 'เเอร์เย็นมาก'
sv3 = sentence_vectorizer(sentence3, use_mean=True)

print(sv1)
print(sv2)
print(sv3)
# Out:
# [[-6.62401627e-02 -1.06690042e-01  7.88311306e-02  4.18526248e-02
#   -2.00770420e-02 -1.31175249e-02 -6.71000439e-02  6.26714402e-02
#    1.33088030e-01  1.68587269e-01 -2.20197155e-02 -4.51521569e-02
#   -5.23492469e-02  7.22104205e-02  8.61425397e-03 -9.82596391e-02
#   -8.88154757e-02  7.25683311e-02 -1.50791397e-02 -4.12819043e-02
#   -9.23515943e-03  1.02373284e-01  5.72961725e-02  1.07695874e-01
#   -5.09238067e-02 -6.38052290e-02 -3.87141070e-02 -1.27610403e-01
#    1.88591612e-02 -2.26712339e-01  2.12016925e-02 -1.03318552e-01
#   -5.62963290e-02 -6.54368868e-02 -1.40432838e-01  9.70901272e-02
#   -4.24738550e-02  1.54456014e-01 -1.66645070e-02  1.17790693e-01
#   -4.15351167e-02 -2.62877216e-02 -3.24190753e-02 -1.11842050e-01
#   -9.91612344e-03 -9.60731128e-02  1.90536716e-03 -1.02006176e-02
#    1.53948791e-02  5.70735787e-03 -1.63123570e-01 -3.42539075e-02
#   -2.28273678e-03  1.31467424e-02  4.32857592e-02  5.46901149e-02
# ...

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(sv1, sv2)
# Out:
# array([[0.37907656]])

# %%
cosine_similarity(sv1, sv3)
# Out:
# array([[0.37907656]])

# %%
from pythainlp.word_vector import most_similar_cosmul
list_positive = ['แม่น้ำ']
list_negative = ['แม่']
most_similar_cosmul(list_positive, list_negative)
# Out:
# [('มหาสมุทร', 1.3989778757095337),
#  ('ลำน้ำ', 1.3830623626708984),
#  ('ทะเลสาบ', 1.3575310707092285),
#  ('ทะเล', 1.3425623178482056),
#  ('แหล่งน้ำ', 1.3137098550796509),
#  ('ถนน', 1.309936285018921),
#  ('คลอง', 1.2963979244232178),
#  ('ภูเขา', 1.2909015417099),
#  ('สระน้ำ', 1.2864116430282593),
#  ('ดินแดน', 1.2828655242919922)]

# %%
from pythainlp.sentiment import sentiment
text="วันนี้อากาศดีจัง"
sentiment(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-c6fd7ad2e634> in <module>
# ----> 1 from pythainlp.sentiment import sentiment
#       2 text="วันนี้อากาศดีจัง"
#       3 sentiment(text)
#
# ModuleNotFoundError: No module named 'pythainlp.sentiment'

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator

text = "square"

x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)


wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(text)

plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = "แมว กิน ปลา แมว มัน ชอบ นอน นอน กลางวัน นอน แล้ว นอน อีก เป็น สัตว์ ที่ ขี้เกียจ จริงๆ เลย แมว แต่ แมว มัน เข้ากับ คน ได้ดี ฉัน ชอบ แมว"
wordcloud = WordCloud(font_path='THSarabunNew.ttf',
                      relative_scaling = 1.0,
                      min_font_size=4,
                      background_color="white",
                      width=1024,
                      height=768,
                      scale=3,
                      font_step=1,
                      collocations=False,
                      regexp=r"[\u0E00-\u0E7Fa-zA-Z']+",
                      margin=2, random_state=99
                      ).generate(text)
plt.imshow(wordcloud, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
dthai = """ผู้สื่อข่าวรายงานว่า วันนี้ คณะผู้บริหารจากบริษัท สิงห์ปาร์ค เชียงราย จำกัด และ คุณชูศักดิ์ ชื่นประโยชน์ รองประธานกรรมการหอการค้าไทยและประธานกรรมการสถาบันส่งเสริมคุณภาพเกษตรไทย ได้ร่วมเดินทางมายังกรุงโตเกียว ประเทศญี่ปุ่น เพื่อรับใบประกาศนียบัตรมาตรฐานเกษตรปลอดภัย ASIAGAP และ JGAP จากบริษัท อินเตอร์เทค จำกัด ซึ่งเป็นบริษัทผู้ตรวจรับรองของรัฐบาลญี่ปุ่น

โดยมาตรฐาน ASIAGAP และ JGAP นี้เป็นมาตรฐานที่อิงตามระบบการจัดการผลผลิตทางการเกษตรของประเทศญี่ปุ่น อันได้รับการยอมรับจากนานาประเทศว่าเป็นประเทศที่มีความละเอียดใส่ใจสูงสุดมาตรฐานหนึ่งในโลก


สิงห์ปาร์คเชียงราย ถือเป็นผู้ผลิตรายแรกและรายเดียวของประเทศไทย ที่ได้ทุ่มเททำการยกระดับมาตรฐานผลผลิตทางการเกษตรอย่างต่อเนื่อง และได้เข้าสู่การทำมาตรฐาน ASIAGAP และ JGAP ซึ่งในทวีปเอเชีย เทียบเท่ามาตรฐานของ ประเทศญี่ปุ่น เกาหลีใต้ และไต้หวัน ที่ได้รับมาตรฐานนี้มาก่อนแล้ว


มาตรฐานนี้เปิดทางให้สินค้าทางการเกษตรของสิงห์ปาร์คสามารถวางขายได้ในห้างสรรพสินค้าชั้นนำของประเทศญี่ปุ่นที่มีความเข้มงวดด้านความปลอดภัยสูงมาก


สิงห์ปาร์คมั่นใจว่า ระดับมาตรฐานนี้จะเป็นแนวทางต้นแบบให้เกษตรกรของไทยมาศึกษาเพื่อยกระดับมาตรฐานไปด้วยกัน

และด้วยมาตรฐานความปลอดภัยที่ได้รับระดับนี้จากรัฐบาลญี่ปุ่น ผู้บริโภคจึงสามารถมั่นใจในคุณภาพของผลผลิตทางการเกษตรของสิงห์ปาร์คว่าปลอดภัยเหมือนผลผลิตทางการเกษตรที่ชาวญี่ปุ่นรับประทานในประเทศของเขา

ผู้สื่อข่าวรายงานจากกรุงโตเกียว ประเทศญี่ปุ่น"""

# %%
set(word_tokenize(grab_ans, engine='mm'))

# %%
new_text = ' '.join(set(word_tokenize(grab_ans, engine='mm')) -
                    set(pythainlp.corpus.common.thai_stopwords()))
new_text

# %%
set(['อย่างเช่น', 'เเม่']) - set(pythainlp.corpus.common.thai_stopwords())

# %%
word = ' room' * 20
word

# %%
{
    "thailand": {
        "room": 2,
        "far": 1,
    },
    "usa": {
        room: 1
    }
}
df = pd.load_csv('words_by_nation.csv')
df['word']
new_text = ''
for row in df:
    word = df["word"]
    count = df["count"]
    new_text += (' ' + word) * count

# %%
from PIL import Image

mask = np.array(Image.open("sphx_glr_masked_002.png"))

# %%
wordcloud = WordCloud(font_path='THSarabunNew.ttf',
                      relative_scaling = 1.0,
                      min_font_size=4,
                      background_color="white",
                      width=1024,
                      height=768,
                      scale=3,
                      mask=mask,
                      font_step=1,
                      collocations=False,
                      regexp=r"[\u0E00-\u0E7Fa-zA-Z']+",
                      margin=2, random_state=99
                      ).generate(new_text)
# plt.imshow(wordcloud, cmap=plt.cm.gray, interpolation='bilinear')
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[20,20])
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[7,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
mask
